# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data_242_26022026.csv")


df_copy = df.copy()

df_copy['shutheight'] = (
    df_copy['shutheight']
        .replace(0, np.nan)
        .bfill()
)

df_final = (
    df_copy
        .groupby(['hour_ist', 'epc', 'shutheight'], as_index=False)
        .agg({'hourly_count': 'sum'})
)
df_final = df_final.sort_values('hour_ist')
df_final
# Out:
#                hour_ist                       epc  shutheight  hourly_count
# 0   2026-02-26 08:00:00  e00000000000000000000002      424.68            17
# 1   2026-02-26 09:00:00  e00000000000000000000002      424.68           531
# 2   2026-02-26 10:00:00  e00000000000000000000002      424.68            77
# 3   2026-02-26 11:00:00  e00000000000000000000002      424.68            20
# 4   2026-02-26 12:00:00  e00000000000000000000002      424.68           171
# 5   2026-02-26 13:00:00  e00000000000000000000002      424.68           495
# 6   2026-02-26 14:00:00  e00000000000000000000002      424.68           665
# 7   2026-02-26 15:00:00  e00000000000000000000002      424.68           351
# 8   2026-02-26 16:00:00  e00000000000000000000002      424.68           144
# 9   2026-02-26 17:00:00  e00000000000000000000002      424.68           464
# 10  2026-02-26 18:00:00  e00000000000000000000002      424.68           163
# 11  2026-02-26 19:00:00  e00000000000000000000002      424.68           277
# 12  2026-02-26 22:00:00  e00000000000000000000002      424.68            68

# %%
epc_value = "e00000000000000000000002"

df_filtered = df_final[df_final['epc'] == epc_value]

df_filtered
# Out:
#                hour_ist                       epc  shutheight  hourly_count
# 0   2026-02-26 08:00:00  e00000000000000000000002      424.68            17
# 1   2026-02-26 09:00:00  e00000000000000000000002      424.68           531
# 2   2026-02-26 10:00:00  e00000000000000000000002      424.68            77
# 3   2026-02-26 11:00:00  e00000000000000000000002      424.68            20
# 4   2026-02-26 12:00:00  e00000000000000000000002      424.68           171
# 5   2026-02-26 13:00:00  e00000000000000000000002      424.68           495
# 6   2026-02-26 14:00:00  e00000000000000000000002      424.68           665
# 7   2026-02-26 15:00:00  e00000000000000000000002      424.68           351
# 8   2026-02-26 16:00:00  e00000000000000000000002      424.68           144
# 9   2026-02-26 17:00:00  e00000000000000000000002      424.68           464
# 10  2026-02-26 18:00:00  e00000000000000000000002      424.68           163
# 11  2026-02-26 19:00:00  e00000000000000000000002      424.68           277
# 12  2026-02-26 22:00:00  e00000000000000000000002      424.68            68

# %%
df_final[df_final['epc'] == epc_value]['hourly_count'].sum()
# Out:
# np.int64(3443)
