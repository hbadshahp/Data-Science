# %%
name = "Alice"

# %%
age = 25

# %%
is_student = True

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(is_student)
# Out:
# bool

# %% [markdown]
# # Typecasting

# %%
x = int("10")

# %%
x
# Out:
# 10

# %%
y = str(25)

# %%
y
# Out:
# '25'

# %%
z = int(3.9)
z
# Out:
# 3

# %%
lst = list('abc')
lst
# Out:
# ['a', 'b', 'c']

# %%
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'
