# %%
name= "Hussain"

# %%
greeting="Hello"

# %%
message = """This is
a multiline
string."""
message
# Out:
# 'This is\na multiline\nstring.'

# %%
text = "Python"

# %%
text[0]
# Out:
# 'P'

# %%
text[-1]
# Out:
# 'n'

# %%
text[0:2]
# Out:
# 'Py'

# %%
text[:3]
# Out:
# 'Pyt'

# %%
text[3:]
# Out:
# 'hon'

# %% [markdown]
# # String Immutability

# %%
text[0] = 'j'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 text[0] = 'j'
#
# TypeError: 'str' object does not support item assignment

# %%
text.upper()
# Out:
# 'PYTHON'

# %%
" Hellow".strip()
# Out:
# 'Hellow'

# %%
"hello world".split()
# Out:
# ['hello', 'world']

# %%
"-".join(["2025","04","14"])
# Out:
# '2025-04-14'

# %%
"python".find("on")
# Out:
# 4
