# %% [markdown]
# # Arithmatic Operator

# %%
a = 10
b = 5

# %%
# addition
a + b
# Out:
# 15

# %%
# subtraction
a-b
# Out:
# 5

# %%
# Multiplication
a*b
# Out:
# 50

# %%
# Division
# In interviewer ask in division you get int or float
a / b
# Out:
# 2.0

# %%
# Floor Division
# In interviewer ask in floor division you get int or float
a // b
# Out:
# 2

# %%
# Modulus
a % b
# Out:
# 0

# %%
# exponentiation
a ** b
# Out:
# 100000

# %% [markdown]
# # Comparison Operators

# %%
# equal to
a == b
# Out:
# False

# %%
# Not equal to 
a != b
# Out:
# True

# %%
# Greater than
a > b
# Out:
# True

# %%
# Less than
a < b
# Out:
# False

# %%
# Greater or equal
a >= b
# Out:
# True

# %% [markdown]
# # Less or equal
# a <=b

# %% [markdown]
# # Logical Operators

# %%
x = True
y = False

# %%
# and
x and y
# Out:
# False

# %%
# or 
x or y
# Out:
# True

# %%
# not
not x
# Out:
# False

# %% [markdown]
# # Bitwise Operator

# %%
a = bin(5) # conveting decimal value of 5 into binary
b = bin(3)

# %%
a
# Out:
# '0b101'

# %%
a= 5
b = 3

# %%
a & b
# Out:
# 1

# %%
a | b
# Out:
# 7

# %% [markdown]
# # Assignment Operators

# %%
a =5
a += 5
a -= 5
a *= 5
a /= 5
a //= 5
a %= 5
a **= 5

# %% [markdown]
# # Membership & Identity Operators

# %%
lst = [1,2,3]
x = 2

# %%
# present in sequence
x in lst
# Out:
# True

# %%
# Not Present
x not in lst
# Out:
# False

# %%
a = 3
b = 4
a is b
# Out:
# False

# %%
a is not b
# Out:
# True
