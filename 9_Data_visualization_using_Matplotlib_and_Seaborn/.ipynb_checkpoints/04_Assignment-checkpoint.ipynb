# %%
import matplotlib.pyplot as plt
# Data
os_labels = ["Android", "iOS", "Others"]
market_share = [72.5, 26.8, 0.7]

plt.pie(market_share,labels= os_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2505f2a96a0>,
# ...
#  [Text(-0.7143930308186872, 0.8364464104278829, 'Android'),
#   Text(0.695827344654377, -0.8519532301900375, 'iOS'),
#   Text(1.0997340265864763, -0.024188236146842026, 'Others')])

# %%
plt.barh(os_labels,market_share)
# Out:
# <BarContainer object of 3 artists>
