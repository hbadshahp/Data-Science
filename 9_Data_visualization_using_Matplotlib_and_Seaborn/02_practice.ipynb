# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
#plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010] 
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500] 
plt.plot(years, runs) 
plt.xlabel("Year") 
plt.ylabel("Runs Scored") 
plt.title("Sachin Tendulkar's Yearly Runs") 
#plt.show()
# Out:
# Text(0.5, 1.0, "Sachin Tendulkar's Yearly Runs")

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100] 
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0] 
plt.plot(years, kohli, 'ro--',label="Virat Kohli") 
plt.plot(years, sehwag, 'g^:',label="Virender Sehwag") 
plt.xlabel("Year") 
plt.ylabel("Runs Scored") 
plt.title("Performance Comparison") 
plt.legend() 
plt.show()

# %%
plt.plot(years, kohli, color='orange', linestyle='--', label="Kohli") 
plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag") 
plt.plot(years, runs, color='blue', label="Tendulkar") 
plt.legend()

# %%
plt.plot(years, kohli, linewidth=3, label="Kohli") 
plt.plot(years, sehwag, linewidth=2, label="Sehwag") 
plt.legend() 
plt.grid(True) 
plt.tight_layout() 
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#plt.style.use('ggplot')
plt.style.use("seaborn-deep") 
plt.plot(years, kohli, linewidth=3, label="Kohli") 
plt.plot(years, sehwag, linewidth=2, label="Sehwag") 
plt.legend() 
plt.grid(True) 
plt.tight_layout() 
plt.show()

# %%
with plt.xkcd(): 
    plt.plot(years, kohli, label="Kohli")
    plt.plot(years, sehwag, label="Sehwag") 
    plt.title("Epic Battle of the Batsmen") 
    plt.legend() 
    plt.show()

# %%
import numpy as np 
for i in range(50): 
    plt.plot(np.random.rand(100), linewidth=1) 
plt.title("Too Much Data Can Be Confusing!") 
plt.grid(True) 
plt.tight_layout() 
plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2002, 2004, 2006, 2008]
low =600
high = 1500
Kohli = low + (high - low) * np.random.rand(10)
Rohit = low + (high - low) * np.random.rand(10)
Sehwag = low + (high - low) * np.random.rand(10)

plt.style.use('ggplot')
#plt.style.use("seaborn-deep") 
plt.plot(years, Kohli, color='orange', linestyle='--', label="Kohli") 
plt.plot(years, Sehwag, color='green', linestyle='-.', label="Sehwag") 
plt.plot(years, Rohit, color='blue', label="Rohit Sharma")  
plt.legend() 
plt.grid(True) 
plt.tight_layout() 
plt.show()
