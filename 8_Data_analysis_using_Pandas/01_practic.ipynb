# %% [markdown]
# # Core Data Structures in Pandas

# %% [markdown]
# ## SerieS

# %%
import pandas as pd

s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([10,20,30], index=["a","b","c"])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
data = {
    "name":["Alice","Bob","Charlie"],
    "age":[25,30,35],
    "city":["Delhi","Mumbai","Bbanglore"]

}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bbanglore
