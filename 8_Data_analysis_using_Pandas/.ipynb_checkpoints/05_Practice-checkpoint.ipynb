# %%
import pandas as pd

# %% [markdown]
# ### Sorting & Ranking

# %%
df= pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df3=df.sort_values("Year",ascending=False).copy()

# %%
df2 = df.sort_values(["Year","IMDb"],ascending=False).copy()

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df3.head()
# Out:
#             Actor               Film  Year          Genre  \
# 0  Shah Rukh Khan            Pathaan  2023         Action
# 3   Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9   Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
# 7  Hrithik Roshan                War  2019         Action
# 8    Akshay Kumar         Good Newwz  2019         Comedy
#
#    BoxOffice(INR Crore)  IMDb
# 0                  1050   7.2
# 3                   431   5.6
# 9                   266   5.9
# 7                   475   6.5
# 8                   318   7.0

# %%
df.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.head()
# Out:
#             Actor             Film  Year       Genre  BoxOffice(INR Crore)  \
# 0  Shah Rukh Khan          Pathaan  2023      Action                  1050
# 1     Salman Khan  Tiger Zinda Hai  2017      Action                   565
# 2      Aamir Khan           Dangal  2016   Biography                  2024
# 3   Ranbir Kapoor       Brahmastra  2022     Fantasy                   431
# 4   Ranveer Singh        Padmaavat  2018  Historical                   585
#
#    IMDb
# 0   7.2
# 1   6.0
# 2   8.4
# 3   5.6
# 4   7.0

# %%
df["Rank"] = df["IMDb"].rank(method="dense")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df.head()
# Out:
#             Actor             Film  Year       Genre  BoxOffice(INR Crore)  \
# 0  Shah Rukh Khan          Pathaan  2023      Action                  1050
# 1     Salman Khan  Tiger Zinda Hai  2017      Action                   565
# 2      Aamir Khan           Dangal  2016   Biography                  2024
# 3   Ranbir Kapoor       Brahmastra  2022     Fantasy                   431
# 4   Ranveer Singh        Padmaavat  2018  Historical                   585
#
#    IMDb  Rank
# 0   7.2   7.0
# 1   6.0   3.0
# 2   8.4  11.0
# 3   5.6   1.0
# 4   7.0   6.0

# %%
df.rename(columns={"Year":"Film_Year"})
# Out:
#                  Actor                      Film  Film_Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan       2023           Action
# 1          Salman Khan           Tiger Zinda Hai       2017           Action
# 2           Aamir Khan                    Dangal       2016        Biography
# 3        Ranbir Kapoor                Brahmastra       2022          Fantasy
# 4        Ranveer Singh                 Padmaavat       2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun       2018         Thriller
# 6        Rajkummar Rao                     Stree       2018    Horror Comedy
# 7       Hrithik Roshan                       War       2019           Action
# 8         Akshay Kumar                Good Newwz       2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2       2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania       2017  Romantic Comedy
# ...

# %%
df.rename(index={0:"row1",1:"row2"})
# Out:
#                    Actor                      Film  Year            Genre  \
# row1      Shah Rukh Khan                   Pathaan  2023           Action
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6          Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df.head()
# Out:
#             Actor             Film  Year       Genre  BoxOffice(INR Crore)  \
# 0  Shah Rukh Khan          Pathaan  2023      Action                  1050
# 1     Salman Khan  Tiger Zinda Hai  2017      Action                   565
# 2      Aamir Khan           Dangal  2016   Biography                  2024
# 3   Ranbir Kapoor       Brahmastra  2022     Fantasy                   431
# 4   Ranveer Singh        Padmaavat  2018  Historical                   585
#
#    IMDb  Rank
# 0   7.2   7.0
# 1   6.0   3.0
# 2   8.4  11.0
# 3   5.6   1.0
# 4   7.0   6.0

# %%
cols = ["IMDb"] + [col for col in df.columns if col !="IMDb"]
df = df[cols]

# %%
df
# Out:
#     IMDb               Actor                      Film  Year            Genre  \
# 0    7.2      Shah Rukh Khan                   Pathaan  2023           Action
# 1    6.0         Salman Khan           Tiger Zinda Hai  2017           Action
# 2    8.4          Aamir Khan                    Dangal  2016        Biography
# 3    5.6       Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4    7.0       Ranveer Singh                 Padmaavat  2018       Historical
# 5    8.3  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6    7.5       Rajkummar Rao                     Stree  2018    Horror Comedy
# 7    6.5      Hrithik Roshan                       War  2019           Action
# 8    7.0        Akshay Kumar                Good Newwz  2019           Comedy
# 9    5.9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10   6.1        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# ...
