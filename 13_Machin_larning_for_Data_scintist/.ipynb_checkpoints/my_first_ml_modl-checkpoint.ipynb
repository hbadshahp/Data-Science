# %%
from sklearn import tree
# Step 1: Collect training data
features = [[140, 1], [130, 1], [150, 0], [170, 0]] # [weight, texture]
labels = [0, 0, 1, 1] # 0 = Apple, 1 = Orange
# Step 2: Train the model
clf = tree.DecisionTreeClassifier()
clf = clf.fit(features, labels)
# Step 3: Make a prediction
print(clf.predict([[160, 0]])) # Predicts: Orange (1)
# Out:
# [1]

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize=(11,6))

# %%
plot_tree(clf,feature_names=["wight","color"],class_names=["appl","orang"])
# Out:
# [Text(167.4, 163.07999999999998, 'wight <= 145.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = appl'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = appl'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orang')]
